# %% [markdown]
# ## Filters in Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Pandas

# %%
sheet=pd.DataFrame(
    [
    [1,2,3],
    [4,5,6],
    [7,8,9]
],
columns=["A","B","C"],
index=[1,2,3]
)
# Out:
#    A  B  C
# 1  1  2  3
# 2  4  5  6
# 3  7  8  9

# %%
sheet[sheet["B"]==1]
# Out:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []
